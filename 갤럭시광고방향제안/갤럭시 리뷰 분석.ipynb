# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
raw = pd.read_csv('./갤럭시23리뷰수집.csv')

#울트라, 플러스, 기본 구분

#울트라 -> info에 울트라 부분 있음
cond1 = raw['info'].str.contains('울트라')
#플러스 --> info에 플러스 적혀있음
cond2 = raw['info'].str.contains('플러스')
#기본
cond3 = ~(cond1 | cond2)

df_u = raw[cond1]
df_p = raw[cond2]
df_o =raw[cond3]

df_u.to_csv('./갤럭시23울트라.csv', index=False)
df_p.to_csv('./갤럭시23플러스.csv', index=False)
df_o.to_csv('./갤럭시23.csv', index=False)

# %%
#울트라

#구입 색상 구분
raw2 = pd.read_csv('./갤럭시23울트라.csv')

cond1 = raw2['info'].str.contains('팬텀블랙')
cond2 = raw2['info'].str.contains('크림')
cond3 = raw2['info'].str.contains('라벤더')    
cond4 = raw2['info'].str.contains('그린')

count_df = pd.DataFrame(index=['크림', '그린', '팬텀블랙', '라벤더'], columns=['개수'])

# 각 조건에 따른 갯수 계산 및 count_df에 저장
count_df.at['팬텀블랙', '개수'] = cond1.sum()
count_df.at['크림', '개수'] = cond2.sum()
count_df.at['라벤더', '개수'] = cond3.sum()
count_df.at['그린', '개수'] = cond4.sum()

count_df
# Out:
#       개수
# 크림    20
# 그린    12
# 팬텀블랙  16
# 라벤더    9

# %%
#플러스

#구입 색상 구분
raw3 = pd.read_csv('./갤럭시23플러스.csv')

cond1 = raw3['info'].str.contains('팬텀블랙')
cond2 = raw3['info'].str.contains('크림')
cond3 = raw3['info'].str.contains('라벤더')    
cond4 = raw3['info'].str.contains('그린')

count_df2 = pd.DataFrame(index=['크림', '그린', '팬텀블랙', '라벤더'], columns=['개수'])

# 각 조건에 따른 갯수 계산 및 count_df에 저장
count_df2.at['팬텀블랙', '개수'] = cond1.sum()
count_df2.at['크림', '개수'] = cond2.sum()
count_df2.at['라벤더', '개수'] = cond3.sum()
count_df2.at['그린', '개수'] = cond4.sum()

count_df2
# Out:
#       개수
# 크림    23
# 그린     5
# 팬텀블랙   8
# 라벤더    9

# %%
#일반

#구입 색상 구분
raw4 = pd.read_csv('./갤럭시23.csv')

cond1 = raw4['info'].str.contains('팬텀블랙')
cond2 = raw4['info'].str.contains('크림')
cond3 = raw4['info'].str.contains('라벤더')    
cond4 = raw4['info'].str.contains('그린')

count_df3 = pd.DataFrame(index=['크림', '그린', '팬텀블랙', '라벤더'], columns=['개수'])

# 각 조건에 따른 갯수 계산 및 count_df에 저장
count_df3.at['팬텀블랙', '개수'] = cond1.sum()
count_df3.at['크림', '개수'] = cond2.sum()
count_df3.at['라벤더', '개수'] = cond3.sum()
count_df3.at['그린', '개수'] = cond4.sum()

count_df3
# Out:
#        개수
# 크림    307
# 그린     98
# 팬텀블랙   89
# 라벤더   160

# %%
#구입 색상
#색상 구분
cond1 = raw['info'].str.contains('팬텀블랙')
cond2 = raw['info'].str.contains('크림')
cond3 = raw['info'].str.contains('라벤더')    
cond4 = raw['info'].str.contains('그린')

# %%
count_df = pd.DataFrame(index=['크림', '그린', '팬텀블랙', '라벤더'], columns=['개수'])

# 각 조건에 따른 갯수 계산 및 count_df에 저장
count_df.at['팬텀블랙', '개수'] = cond1.sum()
count_df.at['크림', '개수'] = cond2.sum()
count_df.at['라벤더', '개수'] = cond3.sum()
count_df.at['그린', '개수'] = cond4.sum()

count_df
# Out:
#        개수
# 크림    350
# 그린    115
# 팬텀블랙  113
# 라벤더   178

# %%
# !pip install pandas wordcloud matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/34/ac/72a4e42e76bf549dfd91791a6b10a9832f046c1d48b5e778be9ec012aa47/wordcloud-1.9.2-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/151.4 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/151.4 kB ? eta -:--:--
#    ---------- ---------------------------- 41.0/151.4 kB 487.6 kB/s eta 0:00:01
#    ---------------------------------------- 151.4/151.4 kB 1.3 MB/s eta 0:00:00
# ...
#   WARNING: The script wordcloud_cli.exe is installed in 'C:\Users\82109\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# !pip install pandas wordcloud matplotlib nltk

import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\82109\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\82109\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('corpora/stopwords.zip')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\82109\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\82109\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Error loading corpora/stopwords.zip: Package
# [nltk_data]     'corpora/stopwords.zip' not found in index
# False

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from nltk.tokenize import word_tokenize
from collections import Counter
from matplotlib import font_manager, rc

raw5 = pd.read_csv('./갤럭시23시리즈 유튜브 후기.csv')
reviews = raw5['reply'].dropna()
text = ' '.join(reviews)

# NLTK를 사용하여 토큰화
tokens = word_tokenize(text)

# 불용어리스트 지정
stop_words = set(['가','게','고','과','네','는','다','도','들','듯','를','에','와','으로',
'은','을','의','이','인','임','자','잘','좀','지','하다','한','너무','많이','진짜','이번에',
'잇섭','님','잇섭님','때문에','더','확실히','하지만', '그리고','역시','상당히','같은데','감사합니다','그','하고','딱','안','아직','이게'
'것이','정말','보면','저는','물론','같습니다','것','합니다','ㅎㅎ','ㅋㅋ','보고','이번에', '.', ',', '?', '!', '(', ')','...','..'
,'이번','수','같은','그냥','같','있'])

# 불용어 제거
tokens = [word for word in tokens if word.lower() not in stop_words]

# '성능이'와 '성능'을 합쳐서 카운트 --> 비슷한 단어 하나로 하기
for i, word in enumerate(tokens):
    if word.lower() == '성능이':
        tokens[i] = '성능'

# 워드클라우드 생성 및 한글 폰트 설정
font_path = 'C:/Windows/Fonts/malgun.ttf'  # 사용하고자 하는 한글 폰트의 경로를 지정
wordcloud = WordCloud(width=800, height=400, background_color='white', font_path=font_path).generate(' '.join(tokens))

# 워드클라우드 시각화
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# 단어 빈도수 분석 및 한글 폰트 설정
word_counter = Counter(tokens)
most_common_words = word_counter.most_common(10)

font_path = 'C:/Windows/Fonts/malgun.ttf'
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

df_word_count = pd.DataFrame(most_common_words, columns=['word', 'count'])

plt.figure(figsize=(10, 6))
plt.bar(df_word_count['word'], df_word_count['count'], color='skyblue')
plt.title('Top 10 Most Common Words')
plt.xlabel('Words')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

print(df_word_count)
# Out:
#   word  count
# 0   성능    117
# 1  갤럭시     93
# 2  아이폰     91
# 3  카메라     60
# 4  울트라     56
# 5  S23     55
# 6   좋은     46
# 7   영상     45
# 8   삼성     40
# 9   있는     40

# %%
# 평점 추출 및 정수형으로 변환
raw4['rating'] = raw4['star'].str.extract('(\d+)')
raw4['rating'] = raw4['rating'].astype(int)

# 부정적인 평점을 0으로 할당
cond1 = raw4['rating'] <= 3
raw4['label'] = 0

# 긍정적인 평점을 1로 할당
cond2 = (raw4['rating'] == 4) | (raw4['rating'] == 5)
raw4['label'][cond2] = 1

# 레이블 분포 출력
label_distribution = raw['label'].value_counts()
print(label_distribution)
# Out:
# 5

# %%
#리뷰 워드 클라우드 분서 --> 사용자 의견 보기
